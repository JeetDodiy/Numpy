# %% [markdown]
# <a href="https://colab.research.google.com/github/JeetDodiy/Numpy/blob/main/learnig_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# Where the List Was give in arry the achange the ther data type to one single data type
# in the List any one data was string the arry chang all the data in to sting formate
a = [4,5,4.5,'jeet']
np.array(a)
# where in list all data in int and one one data was in float arry chang all the data and give float data type
b = [5,6,8.5]
np.array(b)
# Out:
# array([5. , 6. , 8.5])

# %%
# in
